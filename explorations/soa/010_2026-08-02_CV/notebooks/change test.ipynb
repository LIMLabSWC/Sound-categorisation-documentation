# %%
import pandas as pd
import pickle

with open('Data_human_first_dists_V2.pkl', 'rb') as file:
    data = pickle.load(file)


df = pd.DataFrame(data)
# Out:
# C:\Users\Akrami_Lab5\AppData\Local\Temp\ipykernel_16464\3966253707.py:5: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(file)

# %%
df
# Out:
#        Local Timestamp  Participant_Private_ID Participant_ID Distribution  \
# 0         1.649458e+12               6266630.0        Human_1      Uniform
# 1         1.649458e+12               6266630.0        Human_1      Uniform
# 2         1.649458e+12               6266630.0        Human_1      Uniform
# 3         1.649458e+12               6266630.0        Human_1      Uniform
# 4         1.649458e+12               6266630.0        Human_1      Uniform
# ...                ...                     ...            ...          ...
# 26715     1.649448e+12               6265988.0       Human_30      Uniform
# 26716     1.649448e+12               6265988.0       Human_30      Uniform
# 26717     1.649448e+12               6265988.0       Human_30      Uniform
# 26718     1.649448e+12               6265988.0       Human_30      Uniform
# 26719     1.649448e+12               6265988.0       Human_30      Uniform
#
# ...

# %%
df['Participant_Private_ID'].unique()
# Out:
# array([6266630., 6266742., 6268033., 6268045., 6268034., 6268700.,
#        6268705., 6268726., 6268866., 6268864., 6268890., 6268892.,
#        6268904., 6268920., 6843859., 6843885., 6843891., 6844091.,
#        6846513., 6846501., 6846527., 6846555., 6846644., 6846657.,
#        6265060., 6265558., 6265628., 6265983., 6265988.])

# %%
import pandas as pd
import pickle

with open('Data_rat_first_dists_V2.pkl', 'rb') as file:
    data = pickle.load(file)


df = pd.DataFrame(data)
# Out:
# C:\Users\Akrami_Lab5\AppData\Local\Temp\ipykernel_16464\3481035726.py:5: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(file)

# %%
df
# Out:
#        Participant_ID             savetime  stimulus  correct  Answer  \
# 0                EM31  2022-05-06 13:58:01  0.018388      1.0       0
# 1                EM31  2022-05-06 13:58:01  0.047754      1.0       1
# 2                EM31  2022-05-06 13:58:01  0.009764      1.0       0
# 3                EM31  2022-05-06 13:58:01  0.009533      1.0       0
# 4                EM31  2022-05-06 13:58:01  0.010642      1.0       0
# ...               ...                  ...       ...      ...     ...
# 306094           EM73  2023-11-14 11:57:04  0.036529      1.0       1
# 306095           EM73  2023-11-14 11:57:04  0.028937      1.0       1
# 306096           EM73  2023-11-14 11:57:04  0.025284      1.0       1
# 306097           EM73  2023-11-14 11:57:04  0.010255      1.0       0
# 306098           EM73  2023-11-14 11:57:04  0.023109      1.0       1
#
#        Distribution  stim_dur  prestim_time  time_a1_go_cue  go_cue_dur  ...  \
# ...

# %%
df['Participant_ID'].unique()
# Out:
# array(['EM31', 'EM32', 'EM33', 'EM34', 'EM35', 'EM40', 'EM41', 'EM50',
#        'EM51', 'EM54', 'EM55', 'EM56', 'EM57', 'EM58', 'EM59', 'EM60',
#        'EM61', 'EM62', 'EM66', 'EM67', 'EM68', 'EM69', 'EM71', 'EM72',
#        'EM73'], dtype=object)

# %%
import pandas as pd
import pickle

with open('SC_Data_Cleaned.pkl', 'rb') as file:
    data = pickle.load(file)


df = pd.DataFrame(data)
# Out:
# C:\Users\Akrami_Lab5\AppData\Local\Temp\ipykernel_16464\3246374612.py:5: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(file)

# %%
df
# Out:
#        Participant_ID  Trial  choice  correct  No_response  Response_Latency  \
# 0              QP0100      1       1      1.0        False              49.0
# 1              QP0100      2       1      1.0        False               0.0
# 2              QP0100      3       1      0.0        False             966.0
# 3              QP0100      4       1      0.0        False               0.0
# 4              QP0100      5       1      1.0        False              16.0
# ...               ...    ...     ...      ...          ...               ...
# 788674          QP099    629       0      1.0        False               0.0
# 788675          QP099    630       0      1.0        False            2133.0
# 788676          QP099    631       0      1.0        False               0.0
# 788677          QP099    632       0      0.0        False               0.0
# 788678          QP099    633       0      1.0        False               0.0
#
# ...

# %%
df['Participant_ID'].unique()
# Out:
# array(['QP0100', 'QP0101', 'QP0103', 'QP0120', 'QP0121', 'QP0122',
#        'QP0134', 'QP0138', 'QP0140', 'QP0141', 'QP0142', 'QP0151',
#        'QP0152', 'QP0153', 'QP0154', 'QP0155', 'QP0156', 'QP0157',
#        'QP0161', 'QP0162', 'QP049', 'QP050', 'QP062', 'QP063', 'QP070',
#        'QP071', 'QP079', 'QP081', 'QP082', 'QP093', 'QP094', 'QP097',
#        'QP098', 'QP099'], dtype=object)

# %%
import time

import binned_Hybrid_hpc_utils as hpc

start = time.time()

save_path = r"D:\sc_modelling-amir-2025\Final-Hybrid - Copy\human_test.pkl"

hpc.run_pid_repeated_cv(
    species="human",
    p_id=6266630.0,
    save_path=save_path,
    model_mode="all",
    repetition_seeds=[1],      # only one repetition
    cv_folds=2,
    optuna_trials=200,          # increase later
    sampler_type="TPE",
    model_seed_count=5,
    fit_with="conditional",
)

elapsed = time.time() - start

print(f"\nFinished in {elapsed/60:.2f} minutes")
# Out:
# [I 2026-07-01 13:03:04,760] A new study created in memory with name: no-name-ab093a8e-7b33-4b4c-af6e-53c762b1bfec
#   ✱ Running repeated CV
#   ✱ Species: human
#   ✱ Subject: 6266630.0
#   ✱ ID column: Participant_Private_ID
#   ✱ Data path: D:\sc_modelling-amir-2025\Final-Hybrid - Copy\Data_human_first_dists_V2.pkl
#   ✱ Model mode: all
#   ✱ Custom alpha: None
#   ✱ Repetitions: 1
#   ✱ Folds: 2
#   ✱ Model seeds per objective: 5
#   ✱ Sampler: TPE
#
# ...
# Running variant: Hybrid
# ...
#
# --- Repetition 1/1, Fold 1/2 ---
# [I 2026-07-01 13:03:10,468] Trial 0 finished with value: 0.06837284641213423 and parameters: {'sigma_noise': 0.08159018215585934, 'A_repulsion': 0.37739043882567497, 'gamma': 0.5677678301612995, 'sigma_update': 0.1654324459144433, 'eta_learning': 0.3478491667769279, 'sigma_boundary': 1.5333873569415812, 'alpha': 0.345191215678889}. Best is trial 0 with value: 0.06837284641213423.
# ...

# %%
import time

import binned_Hybrid_hpc_utils as hpc

start = time.time()

save_path = r"D:\sc_modelling-amir-2025\Final-Hybrid - Copy\rat_test.pkl"

hpc.run_pid_repeated_cv(
    species="rat",
    p_id="EM57",
    save_path=save_path,
    model_mode="all",
    repetition_seeds=[1],      # only one repetition
    cv_folds=2,
    optuna_trials=200,          # increase later
    sampler_type="TPE",
    model_seed_count=5,
    fit_with="conditional",
)

elapsed = time.time() - start

print(f"\nFinished in {elapsed/60:.2f} minutes")
# Out:
#   ✱ Running repeated CV
#   ✱ Species: rat
#   ✱ Subject: EM57
#   ✱ ID column: Participant_ID
#   ✱ Data path: D:\sc_modelling-amir-2025\Final-Hybrid - Copy\Data_rat_first_dists_V2.pkl
#   ✱ Model mode: all
#   ✱ Custom alpha: None
#   ✱ Repetitions: 1
#   ✱ Folds: 2
#   ✱ Model seeds per objective: 5
#   ✱ Sampler: TPE
#
# ...
# Running variant: Hybrid
# ...
#
# --- Repetition 1/1, Fold 1/2 ---
# [I 2026-07-01 14:49:20,516] A new study created in memory with name: no-name-cc434b16-171f-46b6-b281-7e78129f0784
# [I 2026-07-01 14:50:14,847] Trial 0 finished with value: 0.028881883634828534 and parameters: {'sigma_noise': 0.08159018215585934, 'A_repulsion': 0.37739043882567497, 'gamma': 0.5677678301612995, 'sigma_update': 0.1654324459144433, 'eta_learning': 0.3478491667769279, 'sigma_boundary': 1.5333873569415812, 'alpha': 0.345191215678889}. Best is trial 0 with value: 0.028881883634828534.
# ...

# %%
import time

import binned_Hybrid_hpc_utils as hpc

start = time.time()

save_path = r"D:\sc_modelling-amir-2025\Final-Hybrid - Copy\rat_test.pkl"

hpc.run_pid_repeated_cv(
    species="rat",
    p_id="EM57",
    save_path=save_path,
    model_mode="fixed_alpha",
    custom_alpha=0.3,
    repetition_seeds=[1],      # only one repetition
    cv_folds=2,
    optuna_trials=200,
    sampler_type="TPE",
    model_seed_count=5,
    fit_with="conditional",
)

elapsed = time.time() - start

print(f"\nFinished in {elapsed/60:.2f} minutes")
# Out:
#   ✱ Running repeated CV
#   ✱ Species: rat
#   ✱ Subject: EM57
#   ✱ ID column: Participant_ID
#   ✱ Data path: D:\sc_modelling-amir-2025\Final-Hybrid - Copy\Data_rat_first_dists_V2.pkl
#   ✱ Model mode: fixed_alpha
#   ✱ Custom alpha: 0.3
#   ✱ Repetitions: 1
#   ✱ Folds: 2
#   ✱ Model seeds per objective: 5
#   ✱ Sampler: TPE
#
# ...
# Running variant: Hybrid_fixed_alpha_0p300
# ...
#
# --- Repetition 1/1, Fold 1/2 ---
# [I 2026-07-01 15:47:21,316] A new study created in memory with name: no-name-1b7ee135-4008-4af2-b817-d194d10a9404
# [I 2026-07-01 15:48:20,327] Trial 0 finished with value: 0.03436421131921108 and parameters: {'sigma_noise': 0.08159018215585934, 'A_repulsion': 0.37739043882567497, 'eta_learning': 0.5677678301612995, 'sigma_boundary': 2.2603914995438967, 'gamma': 0.3478491667769279, 'sigma_update': 0.11521894657554463}. Best is trial 0 with value: 0.03436421131921108.
# ...

# %%
import time

import binned_Hybrid_hpc_utils as hpc

start = time.time()

save_path = r"D:\sc_modelling-amir-2025\Final-Hybrid - Copy\mouse_test.pkl"

hpc.run_pid_repeated_cv(
    species="mouse",
    p_id="QP0101",
    save_path=save_path,
    model_mode="all",
    repetition_seeds=[1],      # only one repetition
    cv_folds=2,
    optuna_trials=200,          # increase later
    sampler_type="TPE",
    model_seed_count=5,
    fit_with="conditional",
)

elapsed = time.time() - start

print(f"\nFinished in {elapsed/60:.2f} minutes")
# Out:
#   ✱ Running repeated CV
#   ✱ Species: mouse
#   ✱ Subject: QP0101
#   ✱ ID column: Participant_ID
#   ✱ Data path: D:\sc_modelling-amir-2025\Final-Hybrid - Copy\SC_Data_Cleaned.pkl
#   ✱ Model mode: all
#   ✱ Custom alpha: None
#   ✱ Repetitions: 1
#   ✱ Folds: 2
#   ✱ Model seeds per objective: 5
#   ✱ Sampler: TPE
#
# ...
# Running variant: Hybrid
# ...
#
# --- Repetition 1/1, Fold 1/2 ---
# [I 2026-07-01 16:09:53,223] A new study created in memory with name: no-name-eb0810dd-17a5-46bf-8253-97b9ea1585bf
# [I 2026-07-01 16:11:37,033] Trial 0 finished with value: 0.06992882165968768 and parameters: {'sigma_noise': 0.08159018215585934, 'A_repulsion': 0.37739043882567497, 'gamma': 0.5677678301612995, 'sigma_update': 0.1654324459144433, 'eta_learning': 0.3478491667769279, 'sigma_boundary': 1.5333873569415812, 'alpha': 0.345191215678889}. Best is trial 0 with value: 0.06992882165968768.
# ...

# %%
import pandas as pd
import pickle 

with open('Data_rat_first_dists_V2.pkl', 'rb') as file:
    data = pickle.load(file)


df = pd.DataFrame(data)
# Out:
# C:\Users\Akrami_Lab5\AppData\Local\Temp\ipykernel_16464\1389835061.py:5: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(file)

# %%
df['Distribution'].unique()
# Out:
# array(['Asym_right', 'Uniform', 'Asym_left'], dtype=object)

# %%
df['Distribution'].isna().sum()
# Out:
# np.int64(0)

# %%
df.loc[df['Distribution'].isna(), 'Participant_ID']
# Out:
# Series([], Name: Participant_ID, dtype: object)

# %%
with pd.option_context('display.max_columns', None, 'display.max_rows', None):
    print(df[df['Distribution'].isna()])
# Out:
# Empty DataFrame
# Columns: [Participant_ID, savetime, stimulus, correct, Answer, Distribution, stim_dur, prestim_time, time_a1_go_cue, go_cue_dur, stimulation, choice, Trial, valid, sessiondate, rule, gocue_rewardsound, Response, stim_relative, Reaction Time, performance, block, iti, stim_bin, stim_bin_inc, previous, previous_bin, next_bin, previous2, pre_correct, next, next_correct, previous_choice, diff, diff_bin, Previous_dist, No_response]
# Index: []

# %%
import os

print(os.cpu_count())
# Out:
# 8

# %%
import multiprocessing

print(multiprocessing.cpu_count())
# Out:
# 8

# %%
import os

print(f"PID = {os.getpid()}")
# Out:
# PID = 16464

# %%
pip install psutil
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import psutil
import time

while True:
    print(psutil.cpu_percent(percpu=True))
    time.sleep(1)
# Out:
# [24.1, 25.0, 32.6, 18.4, 28.8, 19.5, 28.1, 24.6]
# [66.7, 59.4, 60.9, 48.4, 59.4, 51.6, 65.6, 59.4]
# [51.5, 42.2, 59.1, 53.1, 51.6, 39.1, 47.7, 53.1]
# [49.3, 50.0, 47.7, 34.4, 62.5, 48.4, 60.9, 45.3]
# [55.9, 64.1, 65.6, 54.7, 60.0, 68.8, 61.5, 56.2]
# [39.7, 38.5, 43.9, 23.1, 37.5, 21.9, 46.2, 29.7]
# [48.5, 36.9, 43.1, 37.5, 49.2, 31.2, 48.4, 25.0]
# [47.1, 46.2, 50.7, 33.8, 51.5, 56.9, 50.8, 33.8]
# [75.4, 78.1, 81.5, 71.9, 78.5, 67.2, 82.8, 71.9]
# [47.1, 25.4, 42.4, 21.5, 43.1, 27.0, 35.4, 25.4]
# [47.1, 27.7, 49.3, 39.1, 33.8, 38.5, 56.1, 26.2]
# [36.2, 26.6, 34.4, 23.4, 37.5, 21.9, 38.5, 23.4]
# [40.6, 26.2, 41.5, 35.9, 39.4, 33.3, 43.9, 26.6]
# [40.6, 35.4, 35.4, 29.7, 34.4, 34.4, 42.2, 30.8]
# [45.6, 32.8, 47.8, 23.4, 37.5, 25.0, 26.6, 30.8]
# [43.3, 45.3, 41.8, 37.5, 46.9, 26.2, 42.2, 37.5]
# [27.7, 28.1, 43.8, 28.1, 29.2, 20.3, 35.9, 26.2]
# [53.6, 48.4, 55.4, 37.5, 57.6, 47.7, 46.9, 45.3]
# [38.8, 39.1, 35.8, 23.1, 38.5, 16.9, 38.5, 17.2]
# ...

# %%
import psutil

print(psutil.cpu_percent(interval=1))
# Out:
# 54.8

# %%
import time

import binned_Hybrid_hpc_utils as hpc

start = time.time()

save_path = r"D:\sc_modelling-amir-2025\Final-Hybrid - Copy\human_test.pkl"


hpc.run_pid_repeated_cv(
    species="human",
    p_id=6266630.0,
    save_path=save_path,
    model_mode="all",
    repetition_seeds=[1,2],
    cv_folds=2,
    optuna_trials=20,
    sampler_type="TPE",
    model_seed_count=5,
    fit_with="conditional",
    parallel_jobs=6,
)



elapsed = time.time() - start

print(f"\nFinished in {elapsed/60:.2f} minutes")
# Out:
#   ✱ Running repeated CV
#   ✱ Species: human
#   ✱ Subject: 6266630.0
#   ✱ ID column: Participant_Private_ID
#   ✱ Data path: D:\sc_modelling-amir-2025\Final-Hybrid - Copy\Data_human_first_dists_V2.pkl
#   ✱ Model mode: all
#   ✱ Custom alpha: None
#   ✱ Repetitions: 2
#   ✱ Folds: 2
#   ✱ Model seeds per objective: 5
#   ✱ Sampler: TPE
#   ✔ Results saved to D:\sc_modelling-amir-2025\Final-Hybrid - Copy\human_test.pkl
#   ✔ Completed human subject 6266630.0
# run_pid_repeated_cv executed in 530.00 seconds.
#
# Finished in 8.83 minutes

# %%
import pickle 

with open('human_test.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
data['variants']['Hybrid']['partitions'][1]
# Out:
# {'repetition_idx': 2,
#  'partition_seed': 2,
#  'blocks_in_folds': [[np.int64(17),
#    np.int64(16),
#    np.int64(5),
#    np.int64(14),
#    np.int64(15),
#    np.int64(10),
#    np.int64(3),
#    np.int64(21),
#    np.int64(20),
#    np.int64(1),
#    np.int64(4),
#    np.int64(11)],
#   [np.int64(9),
#    np.int64(18),
#    np.int64(22),
#    np.int64(13),
#    np.int64(0),
#    np.int64(19),
#    np.int64(8),
#    np.int64(23),
#    np.int64(2),
#    np.int64(6),
#    np.int64(12),
#    np.int64(7)]]}

# %%
import time

import binned_Hybrid_hpc_utils as hpc

start = time.time()

save_path = r"D:\sc_modelling-amir-2025\Final-Hybrid - Copy\mouse_test.pkl"


hpc.run_pid_repeated_cv(
    species="mouse",
    p_id="QP0101",
    save_path=save_path,
    model_mode="all",
    repetition_seeds=[1,2],
    cv_folds=2,
    optuna_trials=3,
    sampler_type="TPE",
    model_seed_count=5,
    fit_with="conditional",
    parallel_jobs=6,
)



elapsed = time.time() - start

print(f"\nFinished in {elapsed/60:.2f} minutes")
# Out:
#   ✱ Running repeated CV
#   ✱ Species: mouse
#   ✱ Subject: QP0101
#   ✱ ID column: Participant_ID
#   ✱ Data path: D:\sc_modelling-amir-2025\Final-Hybrid - Copy\SC_Data_Cleaned.pkl
#   ✱ Model mode: all
#   ✱ Custom alpha: None
#   ✱ Repetitions: 2
#   ✱ Folds: 2
#   ✱ Model seeds per objective: 5
#   ✱ Sampler: TPE
# PID=20888  Memory=0.07 GB
# PID=17592  Memory=0.07 GB
# PID=19212  Memory=0.07 GB
# PID=19604  Memory=0.07 GB
# PID=16396  Memory=0.07 GB
# PID=21932  Memory=0.07 GB
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 10
#       5 start = time.time()
#       7 save_path = r"D:\sc_modelling-amir-2025\Final-Hybrid - Copy\mouse_test.pkl"
# ---> 10 hpc.run_pid_repeated_cv(
#      11     species="mouse",
#      12     p_id="QP0101",
#      13     save_path=save_path,
#      14     model_mode="all",
#      15     repetition_seeds=[1,2],
# ...

# %%
import time
import importlib
import binned_Hybrid_hpc_utils as hpc

importlib.reload(hpc)

start = time.time()

save_path = r"D:\sc_modelling-amir-2025\Final-Hybrid - Copy\test_full_alpha_scan.pkl"

hpc.run_pid_repeated_cv(
    species="human",
    p_id=6266630.0,
    save_path=save_path,
    fit_mode="full_alpha_scan",
    model_mode="fixed_alpha",
    alpha_values=[0.1, 0.2],   # test only 2 alphas first
    optuna_trials=5,           # tiny test
    sampler_type="TPE",
    model_seed_count=2,
    fit_with="conditional",
    parallel_jobs=2,
)

elapsed = time.time() - start
print(f"\nFinished in {elapsed/60:.2f} minutes")
# Out:
#   ✱ Running model fitting
#   ✱ Fit mode: full_alpha_scan
#   ✱ Species: human
#   ✱ Subject: 6266630.0
#   ✱ ID column: Participant_Private_ID
#   ✱ Data path: D:\sc_modelling-amir-2025\Final-Hybrid - Copy\Data_human_first_dists_V2.pkl
#   ✱ Model mode: fixed_alpha
#   ✱ Custom alpha: None
#   ✱ Alpha values: [0.1, 0.2]
#   ✱ Repetitions: 10
#   ✱ Folds: 2
#   ✱ Trials: 5
#   ✱ Model seeds: 2
#   ✱ Sampler: TPE
#   ✱ Parallel jobs: 2
#   ✔ Results saved to D:\sc_modelling-amir-2025\Final-Hybrid - Copy\test_full_alpha_scan.pkl
#   ✔ Completed full_alpha_scan fitting for human subject 6266630.0
# run_pid_repeated_cv executed in 29.27 seconds.
#
# Finished in 0.49 minutes
